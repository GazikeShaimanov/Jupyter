# %%
import requests
import xmltodict

url = "http://www.cbr.ru/scripts/XML_daily.asp"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><ValCurs Date="15.02.2024" name="Foreign Currency Market"><Valute ID="R01010"><NumCode>036</NumCode><CharCode>AUD</CharCode><Nominal>1</Nominal><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>59,1014</Value><VunitRate>59,1014</VunitRate></Valute><Valute ID="R01020A"><NumCode>944</NumCode><CharCode>AZN</CharCode><Nominal>1</Nominal><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><Value>53,7833</Value><VunitRate>53,7833</VunitRate></Valute><Valute ID="R01035"><NumCode>826</NumCode><CharCode>GBP</CharCode><Nominal>1</Nominal><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><Value>115,2130</Value><VunitRate>115,213</VunitRate></Valute><Valute ID="R01060"><NumCode>051</NumCode><CharCode>AMD</CharCode><Nominal>100</Nominal><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xf5 \xe4\xf0\xe0\xec\xee\xe2</Name><Value>22,6557</Value><VunitRate>0,226557</VunitRate></Valute><Valute ID="R01090B"><NumCode>933</NumCode><CharCode>BYN</CharCode><Nominal>1</Nominal><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><Value>28,2921</Value><VunitRate>28,2921</VunitRate></Valute><Valute ID="R01100"><NumCode>975</NumCode><CharCode>BGN</CharCode><Nominal>1</Nominal><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><Value>50,4553</Value><VunitRate>50,4553</VunitRate></Valute><Valute ID="R01115"><NumCode>986</NumCode><CharCode>BRL</CharCode><Nominal>1</Nominal><Name>\xc1\xf0\xe0\xe7\xe8\xeb\xfc\xf1\xea\xe8\xe9 \xf0\xe5\xe0\xeb</Name><Value>18,3915</Value><VunitRate>18,3915</VunitRate></Valute><Valute ID="R01135"><NumCode>348</NumCode><CharCode>HUF</CharCode><Nominal>100</Nominal><Name>\xc2\xe5\xed\xe3\xe5\xf0\xf1\xea\xe8\xf5 \xf4\xee\xf0\xe8\xed\xf2\xee\xe2</Name><Value>25,2065</Value><VunitRate>0,252065</VunitRate></Valute><Valute ID="R01150"><NumCode>704</NumCode><CharCode>VND</CharCode><Nominal>10000</Nominal><Name>\xc2\xfc\xe5\xf2\xed\xe0\xec\xf1\xea\xe8\xf5 \xe4\xee\xed\xe3\xee\xe2</Name><Value>38,1665</Value><VunitRate>0,00381665</VunitRate></Valute><Valute ID="R01200"><NumCode>344</NumCode><CharCode>HKD</CharCode><Nominal>1</Nominal><Name>\xc3\xee\xed\xea\xee\xed\xe3\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>11,7160</Value><VunitRate>11,716</VunitRate></Valute><Valute ID="R01210"><NumCode>981</NumCode><CharCode>GEL</CharCode><Nominal>1</Nominal><Name>\xc3\xf0\xf3\xe7\xe8\xed\xf1\xea\xe8\xe9 \xeb\xe0\xf0\xe8</Name><Value>34,4804</Value><VunitRate>34,4804</VunitRate></Valute><Valute ID="R01215"><NumCode>208</NumCode><CharCode>DKK</CharCode><Nominal>1</Nominal><Name>\xc4\xe0\xf2\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><Value>13,2373</Value><VunitRate>13,2373</VunitRate></Valute><Valute ID="R01230"><NumCode>784</NumCode><CharCode>AED</CharCode><Nominal>1</Nominal><Name>\xc4\xe8\xf0\xf5\xe0\xec \xce\xc0\xdd</Name><Value>24,8963</Value><VunitRate>24,8963</VunitRate></Valute><Valute ID="R01235"><NumCode>840</NumCode><CharCode>USD</CharCode><Nominal>1</Nominal><Name>\xc4\xee\xeb\xeb\xe0\xf0 \xd1\xd8\xc0</Name><Value>91,4316</Value><VunitRate>91,4316</VunitRate></Valute><Valute ID="R01239"><NumCode>978</NumCode><CharCode>EUR</CharCode><Nominal>1</Nominal><Name>\xc5\xe2\xf0\xee</Name><Value>97,8133</Value><VunitRate>97,8133</VunitRate></Valute><Valute ID="R01240"><NumCode>818</NumCode><CharCode>EGP</CharCode><Nominal>10</Nominal><Name>\xc5\xe3\xe8\xef\xe5\xf2\xf1\xea\xe8\xf5 \xf4\xf3\xed\xf2\xee\xe2</Name><Value>29,5963</Value><VunitRate>2,95963</VunitRate></Valute><Valute ID="R01270"><NumCode>356</NumCode><CharCode>INR</CharCode><Nominal>10</Nominal><Name>\xc8\xed\xe4\xe8\xe9\xf1\xea\xe8\xf5 \xf0\xf3\xef\xe8\xe9</Name><Value>11,0190</Value><VunitRate>1,1019</VunitRate></Valute><Valute ID="R01280"><NumCode>360</NumCode><CharCode>IDR</CharCode><Nominal>10000< ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# {'ValCurs': {'@Date': '15.02.2024',
#   '@name': 'Foreign Currency Market',
#   'Valute': [{'@ID': 'R01010',
#     'NumCode': '036',
#     'CharCode': 'AUD',
#     'Nominal': '1',
#     'Name': 'Австралийский доллар',
#     'Value': '59,1014',
#     'VunitRate': '59,1014'},
#    {'@ID': 'R01020A',
#     'NumCode': '944',
#     'CharCode': 'AZN',
#     'Nominal': '1',
#     'Name': 'Азербайджанский манат',
#     'Value': '53,7833',
#     'VunitRate': '53,7833'},
#    {'@ID': 'R01035',
#     'NumCode': '826',
#     'CharCode': 'GBP',
#     'Nominal': '1',
#     'Name': 'Фунт стерлингов Соединенного королевства',
#     'Value': '115,2130',
#     'VunitRate': '115,213'},
#    {'@ID': 'R01060',
#     'NumCode': '051',
#     'CharCode': 'AMD',
#     'Nominal': '100',
#     'Name': 'Армянских драмов',
#     'Value': '22,6557',
#     'VunitRate': '0,226557'},
#    {'@ID': 'R01090B',
#     'NumCode': '933',
#     'CharCode': 'BYN',
#     'Nominal': '1',
#     'Name': 'Белорусский рубль',
#     'Value': '28,2921',
#     'VunitRate': '28,2921'},
#    {'@ID': 'R01100',
#     'NumCode': '975',
#     'CharCode': 'BGN',
#     'Nominal': '1',
#     'Name': 'Болгарский лев',
#     'Value': '50,4553',
#     'VunitRate': '50,4553'},
#    {'@ID': 'R01115',
#     'NumCode': '986',
#     'CharCode': 'BRL',
#     'Nominal': '1',
#     'Name': 'Бразильский реал',
#     'Value': '18,3915',
#     'VunitRate': '18,3915'},
#    {'@ID': 'R01135',
#     'NumCode': '348',
#     'CharCode': 'HUF',
#     'Nominal': '100',
#     'Name': 'Венгерских форинтов',
#     'Value': '25,2065',
#     'VunitRate': '0,252065'},
#    {'@ID': 'R01150',
#     'NumCode': '704',
#     'CharCode': 'VND',
#     'Nominal': '10000',
#     'Name': 'Вьетнамских донгов',
#     'Value': '38,1665',
#     'VunitRate': '0,00381665'},
#    {'@ID': 'R01200',
#     'NumCode': '344',
#     'CharCode': 'HKD',
#     'Nominal': '1',
#     'Name': 'Гонконгский доллар',
#     'Value': '11,7160',
#     'VunitRate': '11,716'},
#    {'@ID': 'R01210',
#     'NumCode': '981',
#     'CharCode': 'GEL',
#     'Nominal': '1',
#     'Name': 'Грузинский лари',
#     'Value': '34,4804',
#     'VunitRate': '34,4804'},
#    {'@ID': 'R01215',
#     'NumCode': '208',
#     'CharCode': 'DKK',
#     'Nominal': '1',
#     'Name': 'Датская крона',
#     'Value': '13,2373',
#     'VunitRate': '13,2373'},
#    {'@ID': 'R01230',
#     'NumCode': '784',
#     'CharCode': 'AED',
#     'Nominal': '1',
#     'Name': 'Дирхам ОАЭ',
#     'Value': '24,8963',
#     'VunitRate': '24,8963'},
#    {'@ID': 'R01235',
#     'NumCode': '840',
#     'CharCode': 'USD',
#     'Nominal': '1',
#     'Name': 'Доллар США',
#     'Value': '91,4316',
#     'VunitRate': '91,4316'},
#    {'@ID': 'R01239',
#     'NumCode': '978',
#     'CharCode': 'EUR',
#     'Nominal': '1',
#     'Name': 'Евро',
#     'Value': '97,8133',
#     'VunitRate': '97,8133'},
#    {'@ID': 'R01240',
#     'NumCode': '818',
#     'CharCode': 'EGP',
#     'Nominal': '10',
#     'Name': 'Египетских фунтов',
#     'Value': '29,5963',
#     'VunitRate': '2,95963'},
#    {'@ID': 'R01270',
#     'NumCode': '356',
#     'CharCode': 'INR',
#     'Nominal': '10',
#     'Name': 'Индийских рупий',
#     'Value': '11,0190',
#     'VunitRate': '1,1019'},
#    {'@ID': 'R01280',
#     'NumCode': '360',
#     'CharCode': 'IDR',
#     'Nominal': '10000',
#     'Name': 'Индонезийских рупий',
#     'Value': '58,5650',
#     'VunitRate': '0,0058565'},
#    {'@ID': 'R01335',
#     'NumCode': '398',
#     'CharCode': 'KZT',
#     'Nominal': '100',
#     'Name': 'Казахстанских тенге',
#     'Value': '20,4093',
#     'VunitRate': '0,204093'},
#    {'@ID': 'R01350',
#     'NumCode': '124',
#     'CharCode': 'CAD',
#     'Nominal': '1',
#     'Name': 'Канадский доллар',
#     'Value': '67,4473',
#     'VunitRate': '67,4473'},
#    {'@ID': 'R01355',
#     'NumCode': '634',
#     'CharCode': 'QAR',
#     'Nominal': '1',
#     'Name': 'Катарский риал',
#     'Value': '25,1186',
#     'VunitRate': '25,1186'},
#    {'@ID': 'R01370',
#     'NumCode': '417',
#     'CharCode': 'KGS',
#     'Nominal': '10',
#     'Name': 'Киргизских сомов',
#     'Value': '10,2238',
#     'VunitRate': '1,02238'},
#    {'@ID': 'R01375',
#     'NumCode': '156',
#     'CharCode': 'CNY',
#     'Nominal': '1',
#     'Name': 'Китайский юань',
#     'Value': '12,5833',
#     'VunitRate': '12,5833'},
#    {'@ID': 'R01500',
#     'NumCode': '498',
#     'CharCode': 'MDL',
#     'Nominal': '10',
#     'Name': 'Молдавских леев',
#     'Value': '51,3990',
#     'VunitRate': '5,1399'},
#    {'@ID': 'R01530',
#     'NumCode': '554',
#     'CharCode': 'NZD',
#     'Nominal': '1',
#     'Name': 'Новозеландский доллар',
#     'Value': '55,3664',
#     'VunitRate': '55,3664'},
#    {'@ID': 'R01535',
#     'NumCode': '578',
#     'CharCode': 'NOK',
#     'Nominal': '10',
#     'Name': 'Норвежских крон',
#     'Value': '87,3139',
#     'VunitRate': '8,73139'},
#    {'@ID': 'R01565',
#     'NumCode': '985',
#     'CharCode': 'PLN',
#     'Nominal': '1',
#     'Name': 'Польский злотый',
#     'Value': '22,5240',
#     'VunitRate': '22,524'},
#    {'@ID': 'R01585F',
#     'NumCode': '946',
#     'CharCode': 'RON',
#     'Nominal': '1',
#     'Name': 'Румынский лей',
#     'Value': '19,6606',
#     'VunitRate': '19,6606'},
#    {'@ID': 'R01589',
#     'NumCode': '960',
#     'CharCode': 'XDR',
#     'Nominal': '1',
#     'Name': 'СДР (специальные права заимствования)',
#     'Value': '121,2282',
#     'VunitRate': '121,2282'},
#    {'@ID': 'R01625',
#     'NumCode': '702',
#     'CharCode': 'SGD',
#     'Nominal': '1',
#     'Name': 'Сингапурский доллар',
#     'Value': '67,7070',
#     'VunitRate': '67,707'},
#    {'@ID': 'R01670',
#     'NumCode': '972',
#     'CharCode': 'TJS',
#     'Nominal': '10',
#     'Name': 'Таджикских сомони',
#     'Value': '83,4481',
#     'VunitRate': '8,34481'},
#    {'@ID': 'R01675',
#     'NumCode': '764',
#     'CharCode': 'THB',
#     'Nominal': '10',
#     'Name': 'Таиландских батов',
#     'Value': '25,3377',
#     'VunitRate': '2,53377'},
#    {'@ID': 'R01700J',
#     'NumCode': '949',
#     'CharCode': 'TRY',
#     'Nominal': '10',
#     'Name': 'Турецких лир',
#     'Value': '29,7856',
#     'VunitRate': '2,97856'},
#    {'@ID': 'R01710A',
#     'NumCode': '934',
#     'CharCode': 'TMT',
#     'Nominal': '1',
#     'Name': 'Новый туркменский манат',
#     'Value': '26,1233',
#     'VunitRate': '26,1233'},
#    {'@ID': 'R01717',
#     'NumCode': '860',
#     'CharCode': 'UZS',
#     'Nominal': '10000',
#     'Name': 'Узбекских сумов',
#     'Value': '73,2623',
#     'VunitRate': '0,00732623'},
#    {'@ID': 'R01720',
#     'NumCode': '980',
#     'CharCode': 'UAH',
#     'Nominal': '10',
#     'Name': 'Украинских гривен',
#     'Value': '23,9812',
#     'VunitRate': '2,39812'},
#    {'@ID': 'R01760',
#     'NumCode': '203',
#     'CharCode': 'CZK',
#     'Nominal': '10',
#     'Name': 'Чешских крон',
#     'Value': '39,0400',
#     'VunitRate': '3,904'},
#    {'@ID': 'R01770',
#     'NumCode': '752',
#     'CharCode': 'SEK',
#     'Nominal': '10',
#     'Name': 'Шведских крон',
#     'Value': '87,7092',
#     'VunitRate': '8,77092'},
#    {'@ID': 'R01775',
#     'NumCode': '756',
#     'CharCode': 'CHF',
#     'Nominal': '1',
#     'Name': 'Швейцарский франк',
#     'Value': '103,0447',
#     'VunitRate': '103,0447'},
#    {'@ID': 'R01805F',
#     'NumCode': '941',
#     'CharCode': 'RSD',
#     'Nominal': '100',
#     'Name': 'Сербских динаров',
#     'Value': '83,6113',
#     'VunitRate': '0,836113'},
#    {'@ID': 'R01810',
#     'NumCode': '710',
#     'CharCode': 'ZAR',
#     'Nominal': '10',
#     'Name': 'Южноафриканских рэндов',
#     'Value': '47,6750',
#     'VunitRate': '4,7675'},
#    {'@ID': 'R01815',
#     'NumCode': '410',
#     'CharCode': 'KRW',
#     'Nominal': '1000',
#     'Name': 'Вон Республики Корея',
#     'Value': '68,4676',
#     'VunitRate': '0,0684676'},
#    {'@ID': 'R01820',
#     'NumCode': '392',
#     'CharCode': 'JPY',
#     'Nominal': '100',
#     'Name': 'Японских иен',
#     'Value': '60,6995',
#     'VunitRate': '0,606995'}]}}

# %%
items = []
for item in data['ValCurs']['Valute']:
    items.append(item)
items
# Out:
# [{'@ID': 'R01010',
#   'NumCode': '036',
#   'CharCode': 'AUD',
#   'Nominal': '1',
#   'Name': 'Австралийский доллар',
#   'Value': '59,1014',
#   'VunitRate': '59,1014'},
#  {'@ID': 'R01020A',
#   'NumCode': '944',
#   'CharCode': 'AZN',
#   'Nominal': '1',
#   'Name': 'Азербайджанский манат',
#   'Value': '53,7833',
#   'VunitRate': '53,7833'},
#  {'@ID': 'R01035',
#   'NumCode': '826',
#   'CharCode': 'GBP',
#   'Nominal': '1',
#   'Name': 'Фунт стерлингов Соединенного королевства',
#   'Value': '115,2130',
#   'VunitRate': '115,213'},
#  {'@ID': 'R01060',
#   'NumCode': '051',
#   'CharCode': 'AMD',
#   'Nominal': '100',
#   'Name': 'Армянских драмов',
#   'Value': '22,6557',
#   'VunitRate': '0,226557'},
#  {'@ID': 'R01090B',
#   'NumCode': '933',
#   'CharCode': 'BYN',
#   'Nominal': '1',
#   'Name': 'Белорусский рубль',
#   'Value': '28,2921',
#   'VunitRate': '28,2921'},
#  {'@ID': 'R01100',
#   'NumCode': '975',
#   'CharCode': 'BGN',
#   'Nominal': '1',
#   'Name': 'Болгарский лев',
#   'Value': '50,4553',
#   'VunitRate': '50,4553'},
#  {'@ID': 'R01115',
#   'NumCode': '986',
#   'CharCode': 'BRL',
#   'Nominal': '1',
#   'Name': 'Бразильский реал',
#   'Value': '18,3915',
#   'VunitRate': '18,3915'},
#  {'@ID': 'R01135',
#   'NumCode': '348',
#   'CharCode': 'HUF',
#   'Nominal': '100',
#   'Name': 'Венгерских форинтов',
#   'Value': '25,2065',
#   'VunitRate': '0,252065'},
#  {'@ID': 'R01150',
#   'NumCode': '704',
#   'CharCode': 'VND',
#   'Nominal': '10000',
#   'Name': 'Вьетнамских донгов',
#   'Value': '38,1665',
#   'VunitRate': '0,00381665'},
#  {'@ID': 'R01200',
#   'NumCode': '344',
#   'CharCode': 'HKD',
#   'Nominal': '1',
#   'Name': 'Гонконгский доллар',
#   'Value': '11,7160',
#   'VunitRate': '11,716'},
#  {'@ID': 'R01210',
#   'NumCode': '981',
#   'CharCode': 'GEL',
#   'Nominal': '1',
#   'Name': 'Грузинский лари',
#   'Value': '34,4804',
#   'VunitRate': '34,4804'},
#  {'@ID': 'R01215',
#   'NumCode': '208',
#   'CharCode': 'DKK',
#   'Nominal': '1',
#   'Name': 'Датская крона',
#   'Value': '13,2373',
#   'VunitRate': '13,2373'},
#  {'@ID': 'R01230',
#   'NumCode': '784',
#   'CharCode': 'AED',
#   'Nominal': '1',
#   'Name': 'Дирхам ОАЭ',
#   'Value': '24,8963',
#   'VunitRate': '24,8963'},
#  {'@ID': 'R01235',
#   'NumCode': '840',
#   'CharCode': 'USD',
#   'Nominal': '1',
#   'Name': 'Доллар США',
#   'Value': '91,4316',
#   'VunitRate': '91,4316'},
#  {'@ID': 'R01239',
#   'NumCode': '978',
#   'CharCode': 'EUR',
#   'Nominal': '1',
#   'Name': 'Евро',
#   'Value': '97,8133',
#   'VunitRate': '97,8133'},
#  {'@ID': 'R01240',
#   'NumCode': '818',
#   'CharCode': 'EGP',
#   'Nominal': '10',
#   'Name': 'Египетских фунтов',
#   'Value': '29,5963',
#   'VunitRate': '2,95963'},
#  {'@ID': 'R01270',
#   'NumCode': '356',
#   'CharCode': 'INR',
#   'Nominal': '10',
#   'Name': 'Индийских рупий',
#   'Value': '11,0190',
#   'VunitRate': '1,1019'},
#  {'@ID': 'R01280',
#   'NumCode': '360',
#   'CharCode': 'IDR',
#   'Nominal': '10000',
#   'Name': 'Индонезийских рупий',
#   'Value': '58,5650',
#   'VunitRate': '0,0058565'},
#  {'@ID': 'R01335',
#   'NumCode': '398',
#   'CharCode': 'KZT',
#   'Nominal': '100',
#   'Name': 'Казахстанских тенге',
#   'Value': '20,4093',
#   'VunitRate': '0,204093'},
#  {'@ID': 'R01350',
#   'NumCode': '124',
#   'CharCode': 'CAD',
#   'Nominal': '1',
#   'Name': 'Канадский доллар',
#   'Value': '67,4473',
#   'VunitRate': '67,4473'},
#  {'@ID': 'R01355',
#   'NumCode': '634',
#   'CharCode': 'QAR',
#   'Nominal': '1',
#   'Name': 'Катарский риал',
#   'Value': '25,1186',
#   'VunitRate': '25,1186'},
#  {'@ID': 'R01370',
#   'NumCode': '417',
#   'CharCode': 'KGS',
#   'Nominal': '10',
#   'Name': 'Киргизских сомов',
#   'Value': '10,2238',
#   'VunitRate': '1,02238'},
#  {'@ID': 'R01375',
#   'NumCode': '156',
#   'CharCode': 'CNY',
#   'Nominal': '1',
#   'Name': 'Китайский юань',
#   'Value': '12,5833',
#   'VunitRate': '12,5833'},
#  {'@ID': 'R01500',
#   'NumCode': '498',
#   'CharCode': 'MDL',
#   'Nominal': '10',
#   'Name': 'Молдавских леев',
#   'Value': '51,3990',
#   'VunitRate': '5,1399'},
#  {'@ID': 'R01530',
#   'NumCode': '554',
#   'CharCode': 'NZD',
#   'Nominal': '1',
#   'Name': 'Новозеландский доллар',
#   'Value': '55,3664',
#   'VunitRate': '55,3664'},
#  {'@ID': 'R01535',
#   'NumCode': '578',
#   'CharCode': 'NOK',
#   'Nominal': '10',
#   'Name': 'Норвежских крон',
#   'Value': '87,3139',
#   'VunitRate': '8,73139'},
#  {'@ID': 'R01565',
#   'NumCode': '985',
#   'CharCode': 'PLN',
#   'Nominal': '1',
#   'Name': 'Польский злотый',
#   'Value': '22,5240',
#   'VunitRate': '22,524'},
#  {'@ID': 'R01585F',
#   'NumCode': '946',
#   'CharCode': 'RON',
#   'Nominal': '1',
#   'Name': 'Румынский лей',
#   'Value': '19,6606',
#   'VunitRate': '19,6606'},
#  {'@ID': 'R01589',
#   'NumCode': '960',
#   'CharCode': 'XDR',
#   'Nominal': '1',
#   'Name': 'СДР (специальные права заимствования)',
#   'Value': '121,2282',
#   'VunitRate': '121,2282'},
#  {'@ID': 'R01625',
#   'NumCode': '702',
#   'CharCode': 'SGD',
#   'Nominal': '1',
#   'Name': 'Сингапурский доллар',
#   'Value': '67,7070',
#   'VunitRate': '67,707'},
#  {'@ID': 'R01670',
#   'NumCode': '972',
#   'CharCode': 'TJS',
#   'Nominal': '10',
#   'Name': 'Таджикских сомони',
#   'Value': '83,4481',
#   'VunitRate': '8,34481'},
#  {'@ID': 'R01675',
#   'NumCode': '764',
#   'CharCode': 'THB',
#   'Nominal': '10',
#   'Name': 'Таиландских батов',
#   'Value': '25,3377',
#   'VunitRate': '2,53377'},
#  {'@ID': 'R01700J',
#   'NumCode': '949',
#   'CharCode': 'TRY',
#   'Nominal': '10',
#   'Name': 'Турецких лир',
#   'Value': '29,7856',
#   'VunitRate': '2,97856'},
#  {'@ID': 'R01710A',
#   'NumCode': '934',
#   'CharCode': 'TMT',
#   'Nominal': '1',
#   'Name': 'Новый туркменский манат',
#   'Value': '26,1233',
#   'VunitRate': '26,1233'},
#  {'@ID': 'R01717',
#   'NumCode': '860',
#   'CharCode': 'UZS',
#   'Nominal': '10000',
#   'Name': 'Узбекских сумов',
#   'Value': '73,2623',
#   'VunitRate': '0,00732623'},
#  {'@ID': 'R01720',
#   'NumCode': '980',
#   'CharCode': 'UAH',
#   'Nominal': '10',
#   'Name': 'Украинских гривен',
#   'Value': '23,9812',
#   'VunitRate': '2,39812'},
#  {'@ID': 'R01760',
#   'NumCode': '203',
#   'CharCode': 'CZK',
#   'Nominal': '10',
#   'Name': 'Чешских крон',
#   'Value': '39,0400',
#   'VunitRate': '3,904'},
#  {'@ID': 'R01770',
#   'NumCode': '752',
#   'CharCode': 'SEK',
#   'Nominal': '10',
#   'Name': 'Шведских крон',
#   'Value': '87,7092',
#   'VunitRate': '8,77092'},
#  {'@ID': 'R01775',
#   'NumCode': '756',
#   'CharCode': 'CHF',
#   'Nominal': '1',
#   'Name': 'Швейцарский франк',
#   'Value': '103,0447',
#   'VunitRate': '103,0447'},
#  {'@ID': 'R01805F',
#   'NumCode': '941',
#   'CharCode': 'RSD',
#   'Nominal': '100',
#   'Name': 'Сербских динаров',
#   'Value': '83,6113',
#   'VunitRate': '0,836113'},
#  {'@ID': 'R01810',
#   'NumCode': '710',
#   'CharCode': 'ZAR',
#   'Nominal': '10',
#   'Name': 'Южноафриканских рэндов',
#   'Value': '47,6750',
#   'VunitRate': '4,7675'},
#  {'@ID': 'R01815',
#   'NumCode': '410',
#   'CharCode': 'KRW',
#   'Nominal': '1000',
#   'Name': 'Вон Республики Корея',
#   'Value': '68,4676',
#   'VunitRate': '0,0684676'},
#  {'@ID': 'R01820',
#   'NumCode': '392',
#   'CharCode': 'JPY',
#   'Nominal': '100',
#   'Name': 'Японских иен',
#   'Value': '60,6995',
#   'VunitRate': '0,606995'}]

# %%
my_array = []
for item in data['ValCurs']['Valute']:
    my_set = [item['CharCode'], item['Name'], item['Value']];
    my_array.append(my_set)
    print(my_set)
# Out:
# ['AUD', 'Австралийский доллар', '59,1014']
# ['AZN', 'Азербайджанский манат', '53,7833']
# ['GBP', 'Фунт стерлингов Соединенного королевства', '115,2130']
# ['AMD', 'Армянских драмов', '22,6557']
# ['BYN', 'Белорусский рубль', '28,2921']
# ['BGN', 'Болгарский лев', '50,4553']
# ['BRL', 'Бразильский реал', '18,3915']
# ['HUF', 'Венгерских форинтов', '25,2065']
# ['VND', 'Вьетнамских донгов', '38,1665']
# ['HKD', 'Гонконгский доллар', '11,7160']
# ['GEL', 'Грузинский лари', '34,4804']
# ['DKK', 'Датская крона', '13,2373']
# ['AED', 'Дирхам ОАЭ', '24,8963']
# ['USD', 'Доллар США', '91,4316']
# ['EUR', 'Евро', '97,8133']
# ['EGP', 'Египетских фунтов', '29,5963']
# ['INR', 'Индийских рупий', '11,0190']
# ['IDR', 'Индонезийских рупий', '58,5650']
# ['KZT', 'Казахстанских тенге', '20,4093']
# ['CAD', 'Канадский доллар', '67,4473']
# ['QAR', 'Катарский риал', '25,1186']
# ['KGS', 'Киргизских сомов', '10,2238']
# ['CNY', 'Китайский юань', '12,5833']
# ['MDL', 'Молдавских леев', '51,3990']
# ['NZD', 'Новозеландский доллар', '55,3664']
# ['NOK', 'Норвежских крон', '87,3139']
# ['PLN', 'Польский злотый', '22,5240']
# ['RON', 'Румынский лей', '19,6606']
# ['XDR', 'СДР (специальные права заимствования)', '121,2282']
# ['SGD', 'Сингапурский доллар', '67,7070']
# ['TJS', 'Таджикских сомони', '83,4481']
# ['THB', 'Таиландских батов', '25,3377']
# ['TRY', 'Турецких лир', '29,7856']
# ['TMT', 'Новый туркменский манат', '26,1233']
# ['UZS', 'Узбекских сумов', '73,2623']
# ['UAH', 'Украинских гривен', '23,9812']
# ['CZK', 'Чешских крон', '39,0400']
# ['SEK', 'Шведских крон', '87,7092']
# ['CHF', 'Швейцарский франк', '103,0447']
# ['RSD', 'Сербских динаров', '83,6113']
# ['ZAR', 'Южноафриканских рэндов', '47,6750']
# ['KRW', 'Вон Республики Корея', '68,4676']
# ['JPY', 'Японских иен', '60,6995']

# %%
my_array
# Out:
# [['AUD', 'Австралийский доллар', '59,1014'],
#  ['AZN', 'Азербайджанский манат', '53,7833'],
#  ['GBP', 'Фунт стерлингов Соединенного королевства', '115,2130'],
#  ['AMD', 'Армянских драмов', '22,6557'],
#  ['BYN', 'Белорусский рубль', '28,2921'],
#  ['BGN', 'Болгарский лев', '50,4553'],
#  ['BRL', 'Бразильский реал', '18,3915'],
#  ['HUF', 'Венгерских форинтов', '25,2065'],
#  ['VND', 'Вьетнамских донгов', '38,1665'],
#  ['HKD', 'Гонконгский доллар', '11,7160'],
#  ['GEL', 'Грузинский лари', '34,4804'],
#  ['DKK', 'Датская крона', '13,2373'],
#  ['AED', 'Дирхам ОАЭ', '24,8963'],
#  ['USD', 'Доллар США', '91,4316'],
#  ['EUR', 'Евро', '97,8133'],
#  ['EGP', 'Египетских фунтов', '29,5963'],
#  ['INR', 'Индийских рупий', '11,0190'],
#  ['IDR', 'Индонезийских рупий', '58,5650'],
#  ['KZT', 'Казахстанских тенге', '20,4093'],
#  ['CAD', 'Канадский доллар', '67,4473'],
#  ['QAR', 'Катарский риал', '25,1186'],
#  ['KGS', 'Киргизских сомов', '10,2238'],
#  ['CNY', 'Китайский юань', '12,5833'],
#  ['MDL', 'Молдавских леев', '51,3990'],
#  ['NZD', 'Новозеландский доллар', '55,3664'],
#  ['NOK', 'Норвежских крон', '87,3139'],
#  ['PLN', 'Польский злотый', '22,5240'],
#  ['RON', 'Румынский лей', '19,6606'],
#  ['XDR', 'СДР (специальные права заимствования)', '121,2282'],
#  ['SGD', 'Сингапурский доллар', '67,7070'],
#  ['TJS', 'Таджикских сомони', '83,4481'],
#  ['THB', 'Таиландских батов', '25,3377'],
#  ['TRY', 'Турецких лир', '29,7856'],
#  ['TMT', 'Новый туркменский манат', '26,1233'],
#  ['UZS', 'Узбекских сумов', '73,2623'],
#  ['UAH', 'Украинских гривен', '23,9812'],
#  ['CZK', 'Чешских крон', '39,0400'],
#  ['SEK', 'Шведских крон', '87,7092'],
#  ['CHF', 'Швейцарский франк', '103,0447'],
#  ['RSD', 'Сербских динаров', '83,6113'],
#  ['ZAR', 'Южноафриканских рэндов', '47,6750'],
#  ['KRW', 'Вон Республики Корея', '68,4676'],
#  ['JPY', 'Японских иен', '60,6995']]
